# %% [markdown]
# # 🎬 أوتوميشن أيمن الشربيني
# ## اضغط ▶️ مرة واحدة بس وانتظر

# %%
# %%bash
# set -e
# cd /content
# echo "1/4 - تثبيت المكتبات..."
# pip install -q diffusers transformers accelerate torchvision pillow edge-tts gradio
# apt-get install -qq ffmpeg
#
# echo "2/4 - تحميل الكود..."
# rm -rf project
# mkdir -p project/ayman_elsherbeny_automation/{core,generation,utils} project/config project/input project/output
#
# cd project
# BASE=https://raw.githubusercontent.com/cherpo1234/ayman-elsherbeny-automation/main
#
# # main.py
# wget -q $BASE/main.py -O main.py
#
# # config.yaml
# wget -q $BASE/config/config.yaml -O config/config.yaml
#
# # __init__.py
# wget -q $BASE/ayman_elsherbeny_automation/__init__.py -O ayman_elsherbeny_automation/__init__.py
# wget -q $BASE/ayman_elsherbeny_automation/config.py -O ayman_elsherbeny_automation/config.py
#
# # core
# wget -q $BASE/ayman_elsherbeny_automation/core/__init__.py -O ayman_elsherbeny_automation/core/__init__.py
# wget -q $BASE/ayman_elsherbeny_automation/core/automation.py -O ayman_elsherbeny_automation/core/automation.py
#
# # generation
# wget -q $BASE/ayman_elsherbeny_automation/generation/__init__.py -O ayman_elsherbeny_automation/generation/__init__.py
# wget -q $BASE/ayman_elsherbeny_automation/generation/video_generator.py -O ayman_elsherbeny_automation/generation/video_generator.py
# wget -q $BASE/ayman_elsherbeny_automation/generation/text_to_image.py -O ayman_elsherbeny_automation/generation/text_to_image.py
# wget -q $BASE/ayman_elsherbeny_automation/generation/audio_generator.py -O ayman_elsherbeny_automation/generation/audio_generator.py
# wget -q $BASE/ayman_elsherbeny_automation/generation/video_merger.py -O ayman_elsherbeny_automation/generation/video_merger.py
#
# # utils
# wget -q $BASE/ayman_elsherbeny_automation/utils/__init__.py -O ayman_elsherbeny_automation/utils/__init__.py
# wget -q $BASE/ayman_elsherbeny_automation/utils/device.py -O ayman_elsherbeny_automation/utils/device.py
# wget -q $BASE/ayman_elsherbeny_automation/utils/logging.py -O ayman_elsherbeny_automation/utils/logging.py
#
# echo "3/4 - تشغيل الأداة..."
# python main.py --simple "منظر طبيعي مع جبال وبحيرة وغروب الشمس" --preset vertical_reels --out تجربة
#
# echo "4/4 - عرض الفيديو..."
# ls -la /content/project/output/
