# %% [markdown]
# # أوتوميشن أيمن الشربيني
# ## Text/Image to Video with Audio
#
# اضغط على ▶️ (Play) لكل خلية بالترتيب

# %%
# 1. تثبيت المكتبات
# !pip install diffusers transformers accelerate torch torchvision torchaudio xformers pillow edge-tts ffmpeg-python click rich pyyaml
# !apt-get install ffmpeg -qq
print('تم التثبيت بنجاح')
# Out:
# ...
# تم التثبيت بنجاح

# %%
# 2. تحميل الكود من GitHub
# %cd /content
# !rm -rf ayman-elsherbeny-automation
# !git clone https://github.com/cherpo1234/ayman-elsherbeny-automation.git
# %cd /content/ayman-elsherbeny-automation
# !find . -type d -name __pycache__ -exec rm -rf {} + 2>/dev/null; find . -name '*.pyc' -delete 2>/dev/null
print('تم تحميل الكود')
# Out:
# Cloning into 'ayman-elsherbeny-automation'...
# remote: Enumerating objects: 42, done.
# remote: Counting objects: 100% (42/42), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 42 (delta 6), reused 42 (delta 6), pack-reused 0 (from 0)
# Receiving objects: 100% (42/42), 37.16 KiB | 309.00 KiB/s, done.
# Resolving deltas: 100% (6/6), done.
# /content/ayman-elsherbeny-automation
# تم تحميل الكود

# %% [markdown]
# ---
# ## 🎬 تشغيل الأداة
#
# غير النص في `prompt` إلى أي وصف عايزه

# %%
# 3. تشغيل إنشاء فيديو من النص
# !python main.py --simple "منظر طبيعي مع جبال وبحيرة وغروب الشمس" --preset vertical_reels --out تجربة_1

from IPython.display import Video
import glob
videos = glob.glob('output/*.mp4')
if videos:
    latest = max(videos, key=__import__('os').path.getctime)
    print(f'\n✅ الفيديو: {latest}')
    Video(latest, width=400)
# Out:
# Traceback (most recent call last):
#   File "/content/ayman-elsherbeny-automation/main.py", line 13, in <module>
#     from ayman_elsherbeny_automation.core.automation import create_automation
#   File "/content/ayman-elsherbeny-automation/ayman_elsherbeny_automation/__init__.py", line 11, in <module>
#     from .config import config, ROOT_DIR, CONFIG_DIR, MODELS_DIR, OUTPUT_DIR, INPUT_DIR, LOGS_DIR
#   File "/content/ayman-elsherbeny-automation/ayman_elsherbeny_automation/config.py", line 7, in <module>
#     from ayman_elsherbeny_automation.utils.logging import logger
#   File "/content/ayman-elsherbeny-automation/ayman_elsherbeny_automation/utils/logging.py", line 7, in <module>
#     from ayman_elsherbeny_automation.config import config
# ImportError: cannot import name 'config' from partially initialized module 'ayman_elsherbeny_automation.config' (most likely due to a circular import) (/content/ayman-elsherbeny-automation/ayman_elsherbeny_automation/config.py)
